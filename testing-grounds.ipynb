# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
import torchvision.transforms as transforms

from PIL import Image

data_path = "images"

"""Below is some early testing"""
"""Might be deleted later"""

# Load data set
train_data = torchvision.datasets.ImageFolder(root=data_path)
# train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
# test_data = torchvision.datasets.ImageFolder(root=TEST_DATA_PATH, transform=TRANSFORM_IMG)
# test_data_loader  = data.DataLoader(test_data, batch_size=BATCH_SIZE, shuffle=True, num_workers=4) 

img, target = train_data[0]

# convert PIL Image to numpy
img_np = np.array(img)

# convert numpy array to PIL Image
img_pil = Image.fromarray(img_np)

# show image with matplotlib
#plt.imshow(img_pil)

# %%
"""Just some early testing with data extraction from .csv"""

columns = ["id", "Name", "Barcode", "Manufacturer", "Amount", "Food-grade", "Material", "Colour", "GS1 Form"]

# usecols is not necessary
products = pd.read_csv("products.csv", usecols=columns)
products
# Out:
#          id                              Name        Barcode Manufacturer  \
# 0       111                    Bølgekartofler  5712873642489      Salling
# 1       116                         Møllehjul  5712874908874      Salling
# 2       117                 Hvidløgsbaguettes  5712873998067      Salling
# 3       118                         Ærter øko  5712873705825  Salling ØKO
# 4       121                     Græskarboller  5701014074067      Salling
# ...     ...                               ...            ...          ...
# 9981  17437                    Icing m. kakao  5701073061336   Dr. Oetker
# 9982  17440  Sort te m. citrus og vanilje øko  3585810088020        Kusmi
# 9983  17444                    Formalet kaffe  8000070001916      Merrild
# 9984  17464                  Stødt sort peber  5712875160349      Salling
# 9985  17466                 Hele muskatnødder  5712875158278      Salling
#
#       Amount GS1 Form  Food-grade     Material         Colour
# 0      900 g      bag        True      plastic  other-colours
# 1      8 stk      bag        True      plastic  other-colours
# 2      350 g      bag        True      plastic  other-colours
# 3      400 g      bag        True      plastic  other-colours
# 4      8 stk      bag        True      plastic  other-colours
# ...      ...      ...         ...          ...            ...
# 9981   190 g      bag        True      plastic  other-colours
# 9982  20 stk      box       False  fibre-based  other-colours
# 9983   400 g      bag        True      plastic  other-colours
# 9984    65 g      jar        True      plastic          clear
# 9985   5 stk      jar        True      plastic          clear
#
# [9986 rows x 9 columns]

# %%
# we just basically find unique GS1 Forms, might be helpful later
gs1_form = products['GS1 Form']
colour = products['Colour']
material = products['Material']

categories = [[np.unique(gs1_form)], [np.unique(material)], np.unique(colour)]
categories[0]
# Out:
# [array(['aerosol', 'bag', 'bottle', 'box', 'brick', 'bucket', 'can',
#         'cup-tub', 'gable-top', 'jar', 'sleeve', 'tray', 'tube'],
#        dtype=object)]

# %%
# extract file name function
def getBarcode(dataset, number):
    barcode = dataset.imgs[number][0];
    barcode = barcode.replace('.jpg', '')
    barcode = barcode.replace('images/train/', '')
    return int(barcode)

#getBarcode(train_data.imgs[0][0])

# %%
barcode = getBarcode(train_data, 0)

def getClass(barcode):
    for i in range(len(products)):
        if products['Barcode'][i] == barcode:
            print(products['GS1 Form'][i])
            break

getClass(250771)
# Out:
# jar
